# %% [markdown]
# <a href="https://colab.research.google.com/github/tapasML/Session9/blob/main/Session_9_Modular_87_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load the controller module (main.py)
#
# ---

# %%
import main
from main import *

# %% [markdown]
# # Load data (dataloader.py)
#
# ---

# %%
loaddata()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Display few images from training data (utils.py)
#
# ---

# %%
displaysampleimage()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# shape of images torch.Size([128, 3, 32, 32])
#  frog truck horse truck

# %% [markdown]
# # Define a Resnet34 model and create one (model_resnet.py)
#
# ---

# %%
# training module create a Resnet34 model
model = createmodel()

# %% [markdown]
# # Display model summary for image. (training.py)
#
# ---
#
#
#
# Note: I am using single channel image for training

# %%
# training module prints model summary
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13           [-1, 64, 32, 32]          36,864
# ...

# %% [markdown]
# # Prepare to train the model. Define loss function, optimizer, scheduler (training.py)
#
# ---

# %%
# before training, define the loss function, optimizer, scheduler
definelossfunction()

# %% [markdown]
# # Train the model for given number of epochs
#
# ---

# %%
model = trainmodel()
# Out:
# torch.Size([128, 3, 32, 32]) torch.Size([128])
# [1,    40] loss: 0.041
# [1,    80] loss: 0.036
# [1,   120] loss: 0.034
# [1,   160] loss: 0.032
# [1,   200] loss: 0.031
# [1,   240] loss: 0.028
# [1,   280] loss: 0.028
# [1,   320] loss: 0.027
# [1,   360] loss: 0.025
# torch.Size([128, 3, 32, 32]) torch.Size([128])
# [2,    40] loss: 0.022
# [2,    80] loss: 0.023
# [2,   120] loss: 0.022
# [2,   160] loss: 0.022
# [2,   200] loss: 0.021
# [2,   240] loss: 0.021
# [2,   280] loss: 0.020
# [2,   320] loss: 0.019
# [2,   360] loss: 0.018
# torch.Size([128, 3, 32, 32]) torch.Size([128])
# [3,    40] loss: 0.016
# [3,    80] loss: 0.016
# [3,   120] loss: 0.016
# [3,   160] loss: 0.016
# [3,   200] loss: 0.016
# [3,   240] loss: 0.016
# [3,   280] loss: 0.016
# [3,   320] loss: 0.015
# [3,   360] loss: 0.015
# torch.Size([128, 3, 32, 32]) torch.Size([128])
# [4,    40] loss: 0.012
# [4,    80] loss: 0.013
# [4,   120] loss: 0.013
# [4,   160] loss: 0.013
# [4,   200] loss: 0.013
# ...

# %% [markdown]
# # Test the model (testing.py)
#
# ---

# %%
testmodel(model)

# %% [markdown]
# # Display 25 misclassified images (utils.py)

# %%
displaymisclassified()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# # Display classwise test statistics (utils.py)
#
# ---

# %%
displayaccuracybyclass()
# Out:
# Accuracy of plane : 82 %
# Accuracy of   car : 92 %
# Accuracy of  bird : 78 %
# Accuracy of   cat : 67 %
# Accuracy of  deer : 81 %
# Accuracy of   dog : 84 %
# Accuracy of  frog : 88 %
# Accuracy of horse : 84 %
# Accuracy of  ship : 96 %
# Accuracy of truck : 87 %

# %% [markdown]
# # Using GradCAM

# %%
import gradcam_main
import grad_cam
from gradcam_main import *
# following are data it uses. Todo: parameterize these

# image_paths = ['samples/cifar-grad.png']
# target_layer = 'layer3' (can go to layer4 also which is 4 dim)
# topk = 1    
# output_dir = 'results'

gradcam_classify()
# Out:
# Images:
# 	#0: samples/cifar-grad.png
# loaded images from path ['samples/cifar-grad.png']
# Grad-CAM in action:
# Grad am file generated  =  results/0-resnet-gradcam-layer3-bird.png
